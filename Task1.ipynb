# %% [markdown]
# <a href="https://colab.research.google.com/github/LeelaSanjeev12/Leela/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IRIS Flower Classification ML Project

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import the Dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data=pd.read_csv(r'/content/gdrive/My Drive/iris.csv')
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# ...

# %% [markdown]
# Extracting Input features and Target Variables

# %%
x=data[['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width']].values
y=data['Class'].values

# %% [markdown]
# Conveting string values into numeric values using Encoder

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y=label_encoder.fit_transform(y)

# %% [markdown]
#   Splitting the dataset into Training and Testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.75,random_state=42)

# %% [markdown]
# Train a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)

# %% [markdown]
# Make a Prediction on Testing Set

# %%
y_pred=model.predict(x_test)

# %% [markdown]
# Evaluate the Model

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %% [markdown]
# Evaluate the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)

# %%
plt.figure(figsize=(14,6))
plt.title('Confusion Matrix')
sns.heatmap(cm,annot=True,fmt='d',cmap='rainbow')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.savefig('Confusion_matrix.png')

# %% [markdown]
# Making Predictions On New Data

# %%
new=[[5.1,4.2,3.6,7.5],[4.3,3.4,7.2,4.5]]
prediction=model.predict(new)
print('Predicted Species:',prediction)
# Out:
# Predicted Species: [2 2]
